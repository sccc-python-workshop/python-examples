# %%
import pyfirmata
from time import sleep
import time
import datetime
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

def blinkLED (pin,message):
    print message
    board.digital[pin].write(1)
    sleep(0.1)
    board.digital[pin].write(0)
    sleep(0.1)

#Associate port and board with pyFirmata    
port = 'COM4'
board = pyfirmata.Arduino(port)

#Use iterator thread to avoid buffer overflow
it = pyfirmata.util.Iterator(board)
it.start()

#Define pins
#If sensor pin is analog use a:number:i
#If sensor pin is digital use d:number:i
sensorPin = board.get_pin('a:0:i')

redPin = 12
greenPin = 13

#Initializing plotly: it needs to be used online, with api_keys and stream_ids 
#To get those, you must open a free account at https://plot.ly/python/getting-started/ 
plotly.tools.set_credentials_file(username='SCCCPythonWorkshop', api_key='fxedi4yuox', 
                                  stream_ids=['shb4im1quw','y1ggfodzuy'])
stream_ids=tls.get_credentials_file()['stream_ids']
print stream_ids
# Out:
# [u'shb4im1quw', u'y1ggfodzuy']

# %%
stream_id=stream_ids[0]
my_stream=go.Stream(token=stream_id,maxpoints=600)
my_trace=go.Scatter(x=[],y=[],mode='lines+markers',stream=my_stream)
data=go.Data([my_trace])
layout=go.Layout(title='Detection from Sound Sensor')
fig=go.Figure(data=data,layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SCCCPythonWorkshop/34.embed" height="525px" width="100%"></iframe>

# %%
s=py.Stream(stream_id)
s.open()

# %%
#Check for Sensor input
while True:
    
    value = sensorPin.read()
    T = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')
    
    while value is None:
        value=0
        pass
    
    print T,value
    
    s.write(dict(x=T,y=value))
    time.sleep(0.5)
        
#Release the board
board.exit()
s.close()
# Out:
# 2016-11-01 19:48:43.154000 0.5024
# 2016-11-01 19:48:43.658000 0.5064
# 2016-11-01 19:48:44.161000 0.5073
# 2016-11-01 19:48:44.664000 0.5064
# 2016-11-01 19:48:45.168000 0.5073
# 2016-11-01 19:48:45.672000 0.5024
# 2016-11-01 19:48:46.174000 0.4809
# 2016-11-01 19:48:46.677000 0.4868
# 2016-11-01 19:48:47.179000 0.4995
# 2016-11-01 19:48:47.682000 0.4858
# 2016-11-01 19:48:48.185000 0.4907
# 2016-11-01 19:48:48.689000 0.4761
# 2016-11-01 19:48:49.191000 0.4858
# 2016-11-01 19:48:49.694000 0.48
# 2016-11-01 19:48:50.196000 0.5122
# 2016-11-01 19:48:50.700000 0.5064
# 2016-11-01 19:48:51.205000 0.5054
# 2016-11-01 19:48:51.709000 0.5103
# 2016-11-01 19:48:52.211000 0.4888
# 2016-11-01 19:48:52.714000 0.5171
# 2016-11-01 19:48:53.217000 0.5953
# 2016-11-01 19:48:53.719000 0.4907
# 2016-11-01 19:48:54.222000 0.4262
# 2016-11-01 19:48:54.725000 0.5249
# 2016-11-01 19:48:55.229000 0.5611
# 2016-11-01 19:48:55.732000 0.4516
# 2016-11-01 19:48:56.234000 0.5044
# 2016-11-01 19:48:56.737000 0.5093
# 2016-11-01 19:48:57.240000 0.479
# 2016-11-01 19:48:57.744000 0.477
# 2016-11-01 19:48:58.247000 0.5015
# 2016-11-01 19:48:58.750000 0.479
# 2016-11-01 19:48:59.253000 0.5005
# 2016-11-01 19:48:59.755000 0.4682
# 2016-11-01 19:49:00.258000 0.4966
# 2016-11-01 19:49:00.761000 0.4946
