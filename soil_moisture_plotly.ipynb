# %%
import pyfirmata
from time import sleep
import time
import datetime
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go

def blinkLED (pin,message):
    print message
    board.digital[pin].write(1)
    sleep(0.1)
    board.digital[pin].write(0)
    sleep(0.1)

#Associate port and board with pyFirmata    
port = 'COM4'
board = pyfirmata.Arduino(port)

#Use iterator thread to avoid buffer overflow
it = pyfirmata.util.Iterator(board)
it.start()

#Define pins
#If sensor pin is analog use a:number:i
#If sensor pin is digital use d:number:i
sensorPin = board.get_pin('a:0:i')

redPin = 12
greenPin = 13

#Initializing plotly: it needs to be used online, with api_keys and stream_ids 
#To get those, you must open a free account at https://plot.ly/python/getting-started/ 
plotly.tools.set_credentials_file(username='SCCCPythonWorkshop', api_key='fxedi4yuox', 
                                  stream_ids=['shb4im1quw','y1ggfodzuy'])
stream_ids=tls.get_credentials_file()['stream_ids']
print stream_ids
# Out:
# [u'shb4im1quw', u'y1ggfodzuy']

# %%
stream_id=stream_ids[0]
my_stream=go.Stream(token=stream_id,maxpoints=600)
my_trace=go.Scatter(x=[],y=[],mode='lines+markers',stream=my_stream)
data=go.Data([my_trace])
layout=go.Layout(title='Detection from Soil Moisture Sensor')
fig=go.Figure(data=data,layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~SCCCPythonWorkshop/38.embed" height="525px" width="100%"></iframe>

# %%
s=py.Stream(stream_id)
s.open()

# %%
#Check for Sensor input
while True:
    
    value = sensorPin.read()
    T = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')
    
    while value is None:
        value=0
        pass
    
    print T,value
    
    
    s.write(dict(x=T,y=value))
    time.sleep(0.5)
    
        
#Release the board
board.exit()
s.close()
# Out:
# 2016-11-01 20:26:59.872000 0.8671
# 2016-11-01 20:27:00.375000 0.8671
# 2016-11-01 20:27:00.878000 0.8671
# 2016-11-01 20:27:01.380000 0.8661
# 2016-11-01 20:27:01.883000 0.8661
# 2016-11-01 20:27:02.386000 0.8661
# 2016-11-01 20:27:02.890000 0.8661
# 2016-11-01 20:27:03.392000 0.8651
# 2016-11-01 20:27:03.895000 0.8661
# 2016-11-01 20:27:04.397000 0.8661
# 2016-11-01 20:27:04.903000 0.8671
# 2016-11-01 20:27:05.405000 0.8661
# 2016-11-01 20:27:05.908000 0.8661
# 2016-11-01 20:27:06.411000 0.8661
# 2016-11-01 20:27:06.914000 0.8661
# 2016-11-01 20:27:07.417000 0.8661
# 2016-11-01 20:27:07.920000 0.8661
# 2016-11-01 20:27:08.423000 0.8651
# 2016-11-01 20:27:08.925000 0.8651
# 2016-11-01 20:27:09.428000 0.8651
# 2016-11-01 20:27:09.930000 0.8651
# 2016-11-01 20:27:40.086000 0.8612
# 2016-11-01 20:27:40.590000 0.8612
# 2016-11-01 20:27:41.092000 0.8592
# 2016-11-01 20:27:41.595000 0.8602
# 2016-11-01 20:27:42.097000 0.8602
# 2016-11-01 20:27:42.600000 0.8602
# 2016-11-01 20:27:43.103000 0.8602
# 2016-11-01 20:27:43.606000 0.8602
# 2016-11-01 20:27:44.108000 0.8602
# 2016-11-01 20:27:44.610000 0.8602
# 2016-11-01 20:27:45.113000 0.8602
# 2016-11-01 20:27:45.617000 0.8602
# 2016-11-01 20:27:46.119000 0.8592
# 2016-11-01 20:27:46.622000 0.8602
# 2016-11-01 20:27:47.125000 0.8592
# 2016-11-01 20:27:47.627000 0.0
# 2016-11-01 20:27:48.129000 0.0
# 2016-11-01 20:27:48.633000 0.0
# 2016-11-01 20:27:49.135000 0.0
# 2016-11-01 20:27:49.637000 0.0303
# 2016-11-01 20:27:50.140000 0.391
# 2016-11-01 20:27:50.642000 0.3969
# 2016-11-01 20:27:51.145000 0.7067
# 2016-11-01 20:27:51.647000 0.6843
# 2016-11-01 20:27:52.149000 0.697
# 2016-11-01 20:27:52.652000 0.7341
# 2016-11-01 20:27:53.154000 0.7175
# 2016-11-01 20:27:53.657000 0.7048
# 2016-11-01 20:27:54.159000 0.7449
# 2016-11-01 20:27:54.661000 0.7107
# 2016-11-01 20:27:55.163000 0.7009
# 2016-11-01 20:27:55.668000 0.738
# 2016-11-01 20:27:56.170000 0.7195
# 2016-11-01 20:27:56.672000 0.7116
# 2016-11-01 20:27:57.175000 0.7204
# 2016-11-01 20:27:57.677000 0.7165
# 2016-11-01 20:27:58.181000 0.7136
# 2016-11-01 20:27:58.683000 0.7195
# 2016-11-01 20:27:59.185000 0.697
# 2016-11-01 20:27:59.688000 0.4731
# 2016-11-01 20:28:00.191000 0.5533
# 2016-11-01 20:28:00.693000 0.5904
# 2016-11-01 20:28:01.196000 0.3001
# 2016-11-01 20:28:01.700000 0.2952
# 2016-11-01 20:28:02.202000 0.5435
# 2016-11-01 20:28:02.704000 0.3597
# 2016-11-01 20:28:03.206000 0.3636
# 2016-11-01 20:28:03.708000 0.4389
# 2016-11-01 20:28:04.212000 0.4252
# 2016-11-01 20:28:04.715000 0.3891
# 2016-11-01 20:28:05.217000 0.349
# 2016-11-01 20:28:05.719000 0.4145
# 2016-11-01 20:28:06.221000 0.4497
# 2016-11-01 20:28:06.724000 0.3109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c57b24608863> in <module>()
#      17
#      18     s.write(dict(x=T,y=value))
# ---> 19     time.sleep(0.5)
#      20
#      21 #    if value > 0.1:
#
# KeyboardInterrupt:
