# %%
import pyfirmata
from time import sleep

def blinkLED (pin,message):
    print message
    #The following command write(1) sends a high signal to LED: it lights up for 1 sec.
    board.digital[pin].write(1) 
    sleep(1)
    #The following command write(0) sends a low signal to LED: it stays dark for 1 sec.
    board.digital[pin].write(0)
    sleep(1)

#Associate port and board with pyFirmata    
port = '/dev/ttyUSB0'
board = pyfirmata.Arduino(port)

#Use iterator thread to avoid buffer overflow
it = pyfirmata.util.Iterator(board)
it.start()

#Define pins
redPin = 13
greenPin = 12

#Perform Blink using custom function
while True:
    blinkLED (redPin, "blinking red")
    blinkLED (greenPin, "blinking green")
                
#Release the board
board.exit()
s.close()
# Out:
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# blinking green
# blinking red
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/usr/lib64/python2.7/threading.py", line 804, in __bootstrap_inner
#     self.run()
#   File "/home/zingale/.local/lib/python2.7/site-packages/pyfirmata/util.py", line 46, in run
#     while self.board.bytes_available():
#   File "/home/zingale/.local/lib/python2.7/site-packages/pyfirmata/pyfirmata.py", line 256, in bytes_available
#     return self.sp.inWaiting()
#   File "/home/zingale/.local/lib/python2.7/site-packages/serial/serialutil.py", line 572, in inWaiting
#     return self.in_waiting
#   File "/home/zingale/.local/lib/python2.7/site-packages/serial/serialposix.py", line 456, in in_waiting
#     s = fcntl.ioctl(self.fd, TIOCINQ, TIOCM_zero_str)
# IOError: [Errno 5] Input/output error
# blinking green
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-1-b4ed302ec1ee> in <module>()
#      26 while True:
#      27     blinkLED (redPin, "blinking red")
# ---> 28     blinkLED (greenPin, "blinking green")
#      29
#      30 #Release the board
#
# <ipython-input-1-b4ed302ec1ee> in blinkLED(pin, message)
#       5     print message
#       6     #The following command write(1) sends a high signal to LED: it lights up for 1 sec.
# ----> 7     board.digital[pin].write(1)
#       8     sleep(1)
#       9     #The following command write(0) sends a low signal to LED: it stays dark for 1 sec.
#
# /home/zingale/.local/lib/python2.7/site-packages/pyfirmata/pyfirmata.pyc in write(self, value)
#     531             if self.mode is OUTPUT:
#     532                 if self.port:
# --> 533                     self.port.write()
#     534                 else:
#     535                     msg = bytearray([DIGITAL_MESSAGE, self.pin_number, value])
#
# /home/zingale/.local/lib/python2.7/site-packages/pyfirmata/pyfirmata.pyc in write(self)
#     424 #        print("type pinnr", type(pin_nr))
#     425         msg = bytearray([DIGITAL_MESSAGE + self.port_number, mask % 128, mask >> 7])
# --> 426         self.board.sp.write(msg)
#     427
#     428     def _update(self, mask):
#
# /home/zingale/.local/lib/python2.7/site-packages/serial/serialposix.pyc in write(self, data)
#     552             except OSError as v:
#     553                 if v.errno != errno.EAGAIN:
# --> 554                     raise SerialException('write failed: {}'.format(v))
#     555                 # still calculate and check timeout
#     556                 if timeout.expired():
#
# SerialException: write failed: [Errno 5] Input/output error
